# %%
import numpy as np
import cv2 
import plotly 
from matplotlib import pyplot as plt 
import os 
import copy

# %%
img_root = "E:\Sem 6\CV\Assignment 3\panaroma_generation"

# %%
img_dir = os.listdir("panaroma_generation")

# %%
print(img_dir)
# Out:
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg']

# %% [markdown]
# 1. Keypoint Detection

# %%
sift_dir = "E:\Sem 6\CV\Assignment 3\sift_keypts"
for i in img_dir : 
    if "1" in i or "2" in i:
        print(i)
        img_pth = os.path.join(img_root,i)
        
        img = cv2.imread(img_pth)
        gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        
        sift = cv2.SIFT_create()
        kp = sift.detect(gray,None)
        
        img=cv2.drawKeypoints(gray,kp,img)
        save = os.path.join(sift_dir,f"{i}")
        cv2.imwrite(save,img)

        img=cv2.drawKeypoints(gray,kp,img,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
        save2 = os.path.join(sift_dir,f"rich_{i}")
        print(save2)
        cv2.imwrite(save2,img)

        sift = cv2.SIFT_create()
        kp, des = sift.detectAndCompute(gray,None)

        txt_file = os.path.join(sift_dir,f"des_{i[0]}.txt")
        np.savetxt(txt_file,des)
        print(kp)
# Out:
# 1.jpg
# E:\Sem 6\CV\Assignment 3\sift_keypts\rich_1.jpg
# (< cv2.KeyPoint 000002394AA65F80>, < cv2.KeyPoint 000002394AA65FB0>, < cv2.KeyPoint 000002394AA65FE0>, < cv2.KeyPoint 000002394AA66010>, < cv2.KeyPoint 000002394AA66040>, < cv2.KeyPoint 000002394AA66070>, < cv2.KeyPoint 000002394AA660A0>, < cv2.KeyPoint 000002394AA660D0>, < cv2.KeyPoint 000002394AA66100>, < cv2.KeyPoint 000002394AA66130>, < cv2.KeyPoint 000002394AA66160>, < cv2.KeyPoint 000002394AA66190>, < cv2.KeyPoint 000002394AA661C0>, < cv2.KeyPoint 000002394AA661F0>, < cv2.KeyPoint 000002394AA66220>, < cv2.KeyPoint 000002394AA66250>, < cv2.KeyPoint 000002394AA66280>, < cv2.KeyPoint 000002394AA662B0>, < cv2.KeyPoint 000002394AA662E0>, < cv2.KeyPoint 000002394AA66310>, < cv2.KeyPoint 000002394AA66340>, < cv2.KeyPoint 000002394AA66370>, < cv2.KeyPoint 000002394AA663A0>, < cv2.KeyPoint 000002394AA663D0>, < cv2.KeyPoint 000002394AA66400>, < cv2.KeyPoint 000002394AA66430>, < cv2.KeyPoint 000002394AA66460>, < cv2.KeyPoint 000002394AA66490>, < cv2.KeyPoint 000002394AA664C0>, < cv2.KeyPoint 000002394AA664F0>, < cv2.KeyPoint 000002394AA66520>, < cv2.KeyPoint 000002394AA66550>, < cv2.KeyPoint 000002394AA66580>, < cv2.KeyPoint 000002394AA665B0>, < cv2.KeyPoint 000002394AA665E0>, < cv2.KeyPoint 000002394AA66610>, < cv2.KeyPoint 000002394AA66640>, < cv2.KeyPoint 000002394AA66670>, < cv2.KeyPoint 000002394AA666A0>, < cv2.KeyPoint 000002394AA666D0>, < cv2.KeyPoint 000002394AA66700>, < cv2.KeyPoint 000002394AA66730>, < cv
eyPoint 000002394AA66AC0>, < cv2.KeyPoint 000002394AA66AF0>, < cv2.KeyPoint 000002394AA66B20>, < cv2.KeyPoint 000002394AA66B50>, < cv2.KeyPoint 000002394AA66B80>, < cv2.KeyPoint 000002394AA66BB0>, < cv2.KeyPoint 000002394AA66BE0>, < cv2.KeyPoint 000002394AA66C10>, < cv2.KeyPoint 000002394AA66C40>, < cv2.KeyPoint 000002394AA66C70>, < cv2.KeyPoint 000002394AA66CA0>, < cv2.KeyPoint 000002394AA66CD0>, < cv2.KeyPoint 000002394AA66D00>, < cv2.KeyPoint 000002394AA66D30>, < cv2.KeyPoint 000002394AA66D60>, < cv2.KeyPoint 000002394AA66D90>, < cv2.KeyPoint 000002394AA66DC0>, < cv2.KeyPoint 000002394AA66DF0>, < cv2.KeyPoint 000002394AA66E20>, < cv2.KeyPoint 000002394AA66E50>, < cv2.KeyPoint 000002394AA66E80>, < cv2.KeyPoint 000002394AA66EB0>, < cv2.KeyPoint 000002394AA66EE0>, < cv2.KeyPoint 000002394AA66F10>, < cv2.KeyPoint 000002394AA66F40>, < cv2.KeyPoint 000002394AA66F70>, < cv2.KeyPoint 000002394AA66FA0>, < cv2.KeyPoint 000002394AA66FD0>, < cv2.KeyPoint 000002394AA67000>, < cv2.KeyPoint 000002394AA67030>, < cv2.KeyPoint 000002394AA67060>, < cv2.KeyPoint 000002394AA67090>, < cv2.KeyPoint 000002394AA670C0>, < cv2.KeyPoint 000002394AA670F0>, < cv2.KeyPoint 000002394AA67120>, < cv2.KeyPoint 000002394AA67150>, < cv2.KeyPoint 000002394AA67180>, < cv2.KeyPoint 000002394AA671B0>, < cv2.KeyPoint 000002394AA671E0>, < cv2.KeyPoint 000002394AA67210>, < cv2.KeyPoint 000002394AA67240>, < cv2.KeyPoint 000002394AA67270>, < cv2.KeyPoint 000002394AA672A0>, < cv2.KeyPoint 000002394AA672D0>, < cv2.KeyPoint 000002394AA67300>, < cv2.KeyPoint 000002394AA67330>, < cv2.KeyPoint 000002394AA67360>, < cv2.KeyPoint 000002394AA67390>, < cv2.KeyPoint 000002394AA673C0>, < cv2.KeyPoint 000002394AA673F0>, < cv2.KeyPoint 000002394AA67420>, < cv2.KeyPoint 000002394AA67450>, < cv2.KeyPoint 000002394AA67480>, < cv2.KeyPoint 000002394AA674B0>, < cv2.KeyPoint 000002394AA674E0>, < cv2.KeyPoint 000002394AA67510>, < cv2.KeyPoint 000002394AA67540>, < cv2.KeyPoint 000002 ...

# %% [markdown]
# 2.Feautre Matching

# %%
def brute_feature_matching(img1, img2): 

    image1 = cv2.imread(os.path.join(img_root,img1), cv2.IMREAD_GRAYSCALE)
    image2 = cv2.imread(os.path.join(img_root,img2), cv2.IMREAD_GRAYSCALE)


    save_pth = "brute_feature_matching"
    sift = cv2.SIFT_create()

    # Detect keypoints and compute descriptors for both images
    keypoints1, descriptors1 = sift.detectAndCompute(image1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(image2, None)

    # Initialize the feature matcher using brute-force matching
    bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

    # Match the descriptors using brute-force matching
    matches_bf = bf.match(descriptors1, descriptors2)

    # Sort the matches by distance (lower is better)
    matches_bf = sorted(matches_bf, key=lambda x: x.distance)

    # Draw the top N matches
    num_matches = 100
    image_matches_bf = cv2.drawMatches(image1, keypoints1, image2, keypoints2, matches_bf[:num_matches], None)

    src_points = np.float32([keypoints1[m.queryIdx].pt for m in matches_bf]).reshape(-1, 1, 2)
    dst_points = np.float32([keypoints2[m.trainIdx].pt for m in matches_bf]).reshape(-1, 1, 2)

    s = os.path.join(save_pth,f"brute_matching_{img1[0]}_{img2[0]}")
    print(s)

    cv2.imwrite(f"{s}.jpg", image_matches_bf)
    # np.savetxt(f"{s}_src_points.txt",src_points)
    # np.savetxt(f"{s}_dst_points.txt",dst_points)

    print(f"image saved at : {s}.jpg " )

    return src_points, dst_points

# %%
src_points_brute = []
dst_points_brute = []

for i in range(len(img_dir)) : 
    if i != len(img_dir) - 1 :
        sb , db = brute_feature_matching(img_dir[i],img_dir[i+1])
        src_points_brute.append(sb)
        dst_points_brute.append(db)



# src_points_brute = []
# dst_points_brute = []

# for i in range(len(img_dir)) : 
#     if i != len(img_dir) - 1 :
#         if "1" in img_dir[i] or "2" in img_dir[i]:
#             sb , db = brute_feature_matching(img_dir[i],img_dir[i+1])
#             src_points_brute.append(sb)
#             dst_points_brute.append(db)
#         else : 
#             _, _ = brute_feature_matching(img_dir[i],img_dir[i+1])
# Out:
# brute_feature_matching\brute_matching_1_2
# image saved at : brute_feature_matching\brute_matching_1_2.jpg
# brute_feature_matching\brute_matching_2_3
# image saved at : brute_feature_matching\brute_matching_2_3.jpg
# brute_feature_matching\brute_matching_3_4
# image saved at : brute_feature_matching\brute_matching_3_4.jpg
# brute_feature_matching\brute_matching_4_5
# image saved at : brute_feature_matching\brute_matching_4_5.jpg
# brute_feature_matching\brute_matching_5_6
# image saved at : brute_feature_matching\brute_matching_5_6.jpg
# brute_feature_matching\brute_matching_6_7
# image saved at : brute_feature_matching\brute_matching_6_7.jpg
# brute_feature_matching\brute_matching_7_8
# image saved at : brute_feature_matching\brute_matching_7_8.jpg

# %%
def flann_matching(img1, img2) : 

    image1 = cv2.imread(os.path.join(img_root,img1), cv2.IMREAD_GRAYSCALE)
    image2 = cv2.imread(os.path.join(img_root,img2), cv2.IMREAD_GRAYSCALE)

    num_matches = 100 
    save_pth = "flann_feature_matching"
    sift = cv2.SIFT_create()
    
    # Detect keypoints and compute descriptors for both images
    keypoints1, descriptors1 = sift.detectAndCompute(image1, None)
    keypoints2, descriptors2 = sift.detectAndCompute(image2, None)

    index_params = dict(algorithm=0, trees=5)
    search_params = dict(checks=100)
    flann = cv2.FlannBasedMatcher(index_params, search_params)

    # Match the descriptors using FLANN matching
    matches_flann = flann.match(descriptors1, descriptors2)

    # Sort the matches by distance (lower is better)
    matches_flann = sorted(matches_flann, key=lambda x: x.distance)

    # Draw the top N matches
    image_matches_flann = cv2.drawMatches(image1, keypoints1, image2, keypoints2, matches_flann[:num_matches], None)

    src_points = np.float32([keypoints1[m.queryIdx].pt for m in matches_flann]).reshape(-1, 1, 2)
    dst_points = np.float32([keypoints2[m.trainIdx].pt for m in matches_flann]).reshape(-1, 1, 2)

    s = os.path.join(save_pth,f"flann_matching_{img1[0]}_{img2[0]}")
    print(s)

    cv2.imwrite(f"{s}.jpg", image_matches_flann)
    # np.savetxt(f"{s}_src_points.txt",src_points)
    # np.savetxt(f"{s}_dst_points.txt",dst_points)

    print(f"image saved at : {s}.jpg " )

    return src_points, dst_points

# %%
src_points_flann = []
dst_points_flann = []

for i in range(len(img_dir)) : 
    if i != len(img_dir) - 1 :
        sf , df = flann_matching(img_dir[i],img_dir[i+1])
        src_points_flann.append(sf)
        dst_points_flann.append(df)



# src_points_flann = []
# dst_points_flann = []

# for i in range(len(img_dir)) : 
#     if i != len(img_dir) - 1 :
#         if "1" in img_dir[i] or "2" in img_dir[i]:
#             sf , df = flann_matching(img_dir[i],img_dir[i+1])
#             src_points_flann.append(sf)
#             dst_points_flann.append(df)
#         else : 
#             _, _ = flann_matching(img_dir[i],img_dir[i+1])
# Out:
# flann_feature_matching\flann_matching_1_2
# image saved at : flann_feature_matching\flann_matching_1_2.jpg
# flann_feature_matching\flann_matching_2_3
# image saved at : flann_feature_matching\flann_matching_2_3.jpg
# flann_feature_matching\flann_matching_3_4
# image saved at : flann_feature_matching\flann_matching_3_4.jpg
# flann_feature_matching\flann_matching_4_5
# image saved at : flann_feature_matching\flann_matching_4_5.jpg
# flann_feature_matching\flann_matching_5_6
# image saved at : flann_feature_matching\flann_matching_5_6.jpg
# flann_feature_matching\flann_matching_6_7
# image saved at : flann_feature_matching\flann_matching_6_7.jpg
# flann_feature_matching\flann_matching_7_8
# image saved at : flann_feature_matching\flann_matching_7_8.jpg

# %% [markdown]
# 3. Homograpghy Estimation

# %%
len(src_points_brute)
# Out:
# 7

# %% [markdown]
# Brute force matching

# %%
homography, mask = cv2.findHomography(src_points_brute[0], dst_points_brute[0], cv2.RANSAC, 5.0)

# Print the estimated homography matrix
print("Estimated Homography Matrix:")
print(homography)
# Out:
# Estimated Homography Matrix:
# [[ 5.28050204e+02 -3.12733007e+01 -1.85290951e+05]
#  [ 1.59084913e+02  3.21052436e+02 -9.72796794e+04]
#  [ 5.46025613e-01 -1.35011049e-02  1.00000000e+00]]

# %%
# # Load the images
# image1 = cv2.imread(os.path.join(img_root,'1.jpg'))
# image2 = cv2.imread(os.path.join(img_root,'2.jpg'))

# # Convert the images to grayscale
# gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
# gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# # Initialize the feature detector and extractor (e.g., SIFT)
# sift = cv2.SIFT_create()

# # Detect keypoints and compute descriptors for both images
# keypoints1, descriptors1 = sift.detectAndCompute(gray1, None)
# keypoints2, descriptors2 = sift.detectAndCompute(gray2, None)

# # Initialize the feature matcher using brute-force matching
# bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

# # Match the descriptors using brute-force matching
# matches = bf.match(descriptors1, descriptors2)

# # Extract the matched keypoints
# src_points = np.float32([keypoints1[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
# dst_points = np.float32([keypoints2[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)

# # Estimate the homography matrix using RANSAC
# homography, mask = cv2.findHomography(src_points, dst_points, cv2.RANSAC, 5.0)

# # Print the estimated homography matrix
# print("Estimated Homography Matrix:")
# print(homography)

# %% [markdown]
# Flann based matching

# %%
homography, mask = cv2.findHomography(src_points_flann[0], dst_points_flann[0], cv2.RANSAC, 5.0)

# Print the estimated homography matrix
print("Estimated Homography Matrix:")
print(homography)
# Out:
# Estimated Homography Matrix:
# [[ 9.85070865e+01 -4.26449231e+00 -3.46094591e+04]
#  [ 2.95305455e+01  6.14283815e+01 -1.81893553e+04]
#  [ 1.00837617e-01  4.77673022e-04  1.00000000e+00]]

# %%
# # Initialize the feature matcher using FLANN matching
# index_params = dict(algorithm=0, trees=5)
# search_params = dict(checks=50)
# flann = cv2.FlannBasedMatcher(index_params, search_params)

# # Match the descriptors using FLANN matching
# matches_flann = flann.match(descriptors1, descriptors2)

# # Sort the matches by distance (lower is better)
# matches = sorted(matches_flann, key=lambda x: x.distance)

# # Extract matching keypoints
# src_points = np.float32([keypoints1[match.queryIdx].pt for match in matches]).reshape(-1, 1, 2)
# dst_points = np.float32([keypoints2[match.trainIdx].pt for match in matches]).reshape(-1, 1, 2)


# # Estimate the homography matrix
# homography, _ = cv2.findHomography(src_points, dst_points, cv2.RANSAC, 5.0)
# print("Estimated Homography Matrix:")
# print(homography)

# %% [markdown]
# 4. Perspective Wrapping

# %%
"""  
 Wrapping 2 and 1 (not 1 and 2 ) 
"""
# Out:
# '  \n Wrapping 2 and 1 (not 1 and 2 ) \n'

# %%
homography, _ = cv2.findHomography(dst_points_flann[0], src_points_flann[0], cv2.RANSAC, 5.0)
print("Estimated Homography Matrix:")
print(homography)
# Out:
# Estimated Homography Matrix:
# [[ 1.20253884e-02 -5.11133690e-03  3.56848677e+02]
#  [-3.01497849e-01  5.79505484e-01  1.24480949e+02]
#  [-9.99174658e-04 -8.38427512e-05  1.00000000e+00]]

# %%
def wrapping(img1,img2,src_flann,dst_flann) : 
    image1 = cv2.imread(os.path.join(img_root,img1))
    image2 = cv2.imread(os.path.join(img_root,img2))
    result_width = image1.shape[1] + image2.shape[1]
    result_height = image1.shape[0]

    homography, _ = cv2.findHomography(dst_flann, src_flann, cv2.RANSAC, 5.0)

    
    warped_image2 = cv2.warpPerspective(image2, homography, (result_width, result_height))

    # Resize the warped image to match the width of the second image
    warped_image2_resized_rs = cv2.resize(warped_image2, (image1.shape[1], image1.shape[0]))

    warped_image2_resized = warped_image2

    # Create the resulting canvas
    result = np.zeros((result_height, result_width, 3), dtype=np.uint8)

    # Copy images onto the resulting canvas
    result[:, :image1.shape[1]] = image1

    res_prin = copy.deepcopy(result)

    res_prin[:, image1.shape[1]:] = warped_image2_resized_rs

    warped_image2_resized[:image1.shape[0] , :image1.shape[1]] = 0  

    # Blending the warped image with the second image using alpha blending
    alpha = 0.5  # blending factor
    blended_image = cv2.addWeighted(warped_image2_resized, alpha, result, 1-alpha, 0)

    blended_save = "blended_img"
    result_save = "separated_wraps"

    bs = os.path.join(blended_save,f"{img1[0]}_{img2[0]}_blend.jpg")
    rs = os.path.join(result_save,f"{img1[0]}_{img2[0]}_sep.jpg")

    cv2.imwrite(bs, blended_image)
    cv2.imwrite(rs, res_prin)

    cv2.imshow('Blended', blended_image)
    print(f"Blended imaged saved at : {bs} ")
    # cv2.imshow('Wraps', res_prin)
    print(f"Separated wraps saved at : {rs} ")
    
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    return

# %%
for i in range(len(img_dir)) : 
    if i != len(img_dir) - 1 :
        wrapping(img_dir[i], img_dir[i+1], src_points_flann[i], dst_points_flann[i])
# Out:
# Blended imaged saved at : blended_img\1_2_blend.jpg
# Separated wraps saved at : separated_wraps\1_2_sep.jpg
# Blended imaged saved at : blended_img\2_3_blend.jpg
# Separated wraps saved at : separated_wraps\2_3_sep.jpg
# Blended imaged saved at : blended_img\3_4_blend.jpg
# Separated wraps saved at : separated_wraps\3_4_sep.jpg
# Blended imaged saved at : blended_img\4_5_blend.jpg
# Separated wraps saved at : separated_wraps\4_5_sep.jpg
# Blended imaged saved at : blended_img\5_6_blend.jpg
# Separated wraps saved at : separated_wraps\5_6_sep.jpg
# Blended imaged saved at : blended_img\6_7_blend.jpg
# Separated wraps saved at : separated_wraps\6_7_sep.jpg
# Blended imaged saved at : blended_img\7_8_blend.jpg
# Separated wraps saved at : separated_wraps\7_8_sep.jpg

# %% [markdown]
# 6. Stitching all images

# %%
import cv2
import os

# Directory containing images to stitch

# Get list of image files in the directory
image_files = [os.path.join(img_root, file) for file in os.listdir(img_root) if file.endswith(( '.jpg'))]

# Read images and store them in a list
images = [cv2.imread(image) for image in image_files]

# Create a stitcher object
stitcher = cv2.Stitcher_create()

# Stitch images
status, stitched_image = stitcher.stitch(images)

if status == cv2.Stitcher_OK:
    # Save or display the stitched image
    cv2.imwrite("stitched_image.jpg", stitched_image)
    cv2.imshow("Stitched Image", stitched_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Stitching failed!")

# %%
# Directory containing images to stitch
blended_root = "blended_img"
# Get list of image files in the directory
image_files = [os.path.join(blended_root, file) for file in os.listdir(blended_root) if file.endswith(( '.jpg'))]

# Read images and store them in a list
images = [cv2.imread(image) for image in image_files]

# Create a stitcher object
stitcher = cv2.Stitcher_create()

# Stitch images
status, stitched_image = stitcher.stitch(images)


cv2.imwrite("stitched_image_custom.jpg", stitched_image)
cv2.imshow("Stitched Image_custom", stitched_image)
cv2.waitKey(0)
cv2.destroyAllWindows()


if status == cv2.Stitcher_OK:
    # Save or display the stitched image
    cv2.imwrite("stitched_image_custom.jpg", stitched_image)
    cv2.imshow("Stitched Image_custom", stitched_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Stitching failed!")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[51], line 17
#      13 status, stitched_image = stitcher.stitch(images)
#      16 # cv2.imwrite("stitched_image_custom.jpg", stitched_image)
# ---> 17 cv2.imshow("Stitched Image_custom", stitched_image)
#      18 cv2.waitKey(0)
#      19 cv2.destroyAllWindows()
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
